# %%
import pandas as pd
import numpy as np
from numpy import mean
from numpy import std

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier 
from sklearn import svm
from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import KFold
from sklearn.model_selection import ShuffleSplit
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.gridspec as gridspec

# %%
df=pd.read_csv(r'C:\Users\kogla\OneDrive\Masaüstü\SWE599\merged.csv').drop("Unnamed: 0", axis=1)
df.head()
# Out:
#   checked_date     company departure_airport arrival_airport departure_time  \
# 0   2022-11-01  AnadoluJet               SAW             ADB       07:30:00
# 1   2022-11-01  AnadoluJet               SAW             ADB       09:20:00
# 2   2022-11-01  AnadoluJet               SAW             ADB       20:55:00
# 3   2022-11-01     Pegasus               SAW             ADB       23:35:00
# 4   2022-11-01     Pegasus               SAW             ADB       09:10:00
#
#   arrival_time departure_date  duration  price_try departure_week_day  ...  \
# 0     08:40:00     2022-11-14  1sa 10dk     506.99             Monday  ...
# 1     10:30:00     2022-11-14  1sa 10dk     506.99             Monday  ...
# 2     22:05:00     2022-11-14  1sa 10dk     506.99             Monday  ...
# 3     00:45:00     2022-11-14  1sa 10dk     539.99             Monday  ...
# 4     10:20:00     2022-11-14  1sa 10dk     542.99             Monday  ...
#
#   departure_day departure_month  remaining_day_to_flight  arrival_city  \
# 0            14              11                       13         Izmir
# 1            14              11                       13         Izmir
# 2            14              11                       13         Izmir
# 3            14              11                       13         Izmir
# 4            14              11                       13         Izmir
#
#    departure_airport_name departure_hour    part_of_day  is_weekend  \
# 0   Sabiha Gökçen Airport              7  Early Morning     Weekday
# 1   Sabiha Gökçen Airport              9        Morning     Weekday
# 2   Sabiha Gökçen Airport             20        Evening     Weekday
# 3   Sabiha Gökçen Airport             23          Night     Weekday
# 4   Sabiha Gökçen Airport              9        Morning     Weekday
#
#   part_of_month duration(min)
# 0        Middle            70
# 1        Middle            70
# 2        Middle            70
# 3        Middle            70
# 4        Middle            70
#
# [5 rows x 22 columns]

# %%
df=df.drop(['checked_date', 'departure_airport', 'arrival_airport', 'duration', 'departure_date'], axis=1)

# %%
df['company'] = df.company.astype('category')
df['departure_airport_name'] = df.departure_airport_name.astype('category')
df['arrival_city'] = df.arrival_city.astype('category')
df['departure_time'] = pd.to_datetime(df['departure_time'],format= '%H:%M:%S' ).dt.time
df['arrival_time'] = pd.to_datetime(df['arrival_time'],format= '%H:%M:%S' ).dt.time
df['part_of_day'] = df.part_of_day.astype('category')
df['departure_week_day'] = df.departure_week_day.astype('category')
df['part_of_month'] = df.part_of_month.astype('category')
df['is_weekend'] = df.is_weekend.astype('category')
df['checked_time'] = pd.to_datetime(df['arrival_time'],format= '%H:%M:%S' ).dt.time
df['checked_week_day'] = df.checked_week_day.astype('category')
df["price_try"] = df["price_try"].astype("int64")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139051 entries, 0 to 139050
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   company                  139051 non-null  category
#  1   departure_time           139051 non-null  object
#  2   arrival_time             139051 non-null  object
#  3   price_try                139051 non-null  int64
#  4   departure_week_day       139051 non-null  category
#  5   checked_time             139051 non-null  object
#  6   checked_week_day         139051 non-null  category
#  7   departure_day            139051 non-null  int64
#  8   departure_month          139051 non-null  int64
#  9   remaining_day_to_flight  139051 non-null  int64
#  10  arrival_city             139051 non-null  category
#  11  departure_airport_name   139051 non-null  category
#  12  departure_hour           139051 non-null  int64
#  13  part_of_day              139051 non-null  category
#  14  is_weekend               139051 non-null  category
#  15  part_of_month            139051 non-null  category
#  16  duration(min)            139051 non-null  int64
# dtypes: category(8), int64(6), object(3)
# memory usage: 10.6+ MB

# %%
df[df["arrival_city"]=="Izmir"].head()
# Out:
#       company departure_time arrival_time  price_try departure_week_day  \
# 0  AnadoluJet       07:30:00     08:40:00        506             Monday
# 1  AnadoluJet       09:20:00     10:30:00        506             Monday
# 2  AnadoluJet       20:55:00     22:05:00        506             Monday
# 3     Pegasus       23:35:00     00:45:00        539             Monday
# 4     Pegasus       09:10:00     10:20:00        542             Monday
#
#   checked_time checked_week_day  departure_day  departure_month  \
# 0     08:40:00          Tuesday             14               11
# 1     10:30:00          Tuesday             14               11
# 2     22:05:00          Tuesday             14               11
# 3     00:45:00          Tuesday             14               11
# 4     10:20:00          Tuesday             14               11
#
#    remaining_day_to_flight arrival_city departure_airport_name  \
# 0                       13        Izmir  Sabiha Gökçen Airport
# 1                       13        Izmir  Sabiha Gökçen Airport
# 2                       13        Izmir  Sabiha Gökçen Airport
# 3                       13        Izmir  Sabiha Gökçen Airport
# 4                       13        Izmir  Sabiha Gökçen Airport
#
#    departure_hour    part_of_day is_weekend part_of_month  duration(min)
# 0               7  Early Morning    Weekday        Middle             70
# 1               9        Morning    Weekday        Middle             70
# 2              20        Evening    Weekday        Middle             70
# 3              23          Night    Weekday        Middle             70
# 4               9        Morning    Weekday        Middle             70

# %%
izmir=df[df["arrival_city"]=="Izmir"]
antalya=df[df["arrival_city"]=="Antalya"]
ankara=df[df["arrival_city"]=="Ankara"]
adana=df[df["arrival_city"]=="Adana"]
trabzon=df[df["arrival_city"]=="Trabzon"]
antep=df[df["arrival_city"]=="Gaziantep"]
bodrum=df[df["arrival_city"]=="Bodrum Milas"]
diyarbakir=df[df["arrival_city"]=="Diyarbakir"]
dalaman=df[df["arrival_city"]=="Dalaman"]
hatay=df[df["arrival_city"]=="Hatay"]
erzurum=df[df["arrival_city"]=="Erzurum"]
kars=df[df["arrival_city"]=="Kars"]
mardin=df[df["arrival_city"]=="Mardin"]

# %% [markdown]
# df= pd.DataFrame({col: df[col].astype('category').cat.codes for col in df}, index=df.index)

# %%
izmir= pd.DataFrame({col: izmir[col].astype('category').cat.codes for col in izmir}, index=izmir.index)
antalya= pd.DataFrame({col: antalya[col].astype('category').cat.codes for col in antalya}, index=antalya.index)
ankara= pd.DataFrame({col: ankara[col].astype('category').cat.codes for col in ankara}, index=ankara.index)
adana= pd.DataFrame({col: adana[col].astype('category').cat.codes for col in adana}, index=adana.index)
trabzon= pd.DataFrame({col: trabzon[col].astype('category').cat.codes for col in trabzon}, index=trabzon.index)
antep= pd.DataFrame({col: antep[col].astype('category').cat.codes for col in antep}, index=antep.index)
bodrum= pd.DataFrame({col: bodrum[col].astype('category').cat.codes for col in bodrum}, index=bodrum.index)
diyarbakir= pd.DataFrame({col: diyarbakir[col].astype('category').cat.codes for col in diyarbakir}, index=diyarbakir.index)
dalaman= pd.DataFrame({col: dalaman[col].astype('category').cat.codes for col in dalaman}, index=dalaman.index)
hatay= pd.DataFrame({col: hatay[col].astype('category').cat.codes for col in hatay}, index=hatay.index)
erzurum= pd.DataFrame({col: erzurum[col].astype('category').cat.codes for col in erzurum}, index=erzurum.index)
kars= pd.DataFrame({col: kars[col].astype('category').cat.codes for col in kars}, index=kars.index)
mardin= pd.DataFrame({col: mardin[col].astype('category').cat.codes for col in mardin}, index=mardin.index)

# %% [markdown]
# ## 1) İzmir

# %%
X = izmir.drop(['price_try'], axis=1)

y = izmir['price_try']
# test_size=0.2 => %20 test, %80 train
# random_state=0 provides to have same results 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 0)

# %%
X_train.shape, X_test.shape
# Out:
# ((13952, 16), (9302, 16))

# %%
forest_izmir = RandomForestClassifier(n_estimators=100).fit(X_train, y_train)

# Predict the Test set results
y_pred = forest.predict(X_test)

# Check accuracy score 
print('Model accuracy score with 100 decision-trees : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score with 100 decision-trees : 0.7059

# %%
feature_scores = pd.Series(forest.feature_importances_, index=X_train.columns).sort_values(ascending=False)

feature_scores

# %% [markdown]
# ## 2) Antalya

# %%
X = antalya.drop(['price_try'], axis=1)

y = antalya['price_try']
# test_size=0.2 => %20 test, %80 train
# random_state=0 provides to have same results 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 0)

X_train.shape, X_test.shape
