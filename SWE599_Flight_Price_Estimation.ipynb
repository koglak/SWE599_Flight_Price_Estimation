# %% [markdown]
# <a href="https://colab.research.google.com/github/koglak/SWE599_Flight_Price_Estimation/blob/main/SWE599_Flight_Price_Estimation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://www.enuygun.com/ucak-bileti/istanbul-ankara-esenboga-havalimani-ista-esb/?gidis=14.11.2022&yetiskin=1&sinif=business&save=1&geotrip=domestic&trip=domestic'
BASE = 'http://philadelphia.craigslist.org/cpg/'

response = requests.get(URL)

soup = BeautifulSoup(response.content)

print(soup)
# Out:
# <!DOCTYPE html>
# ...
